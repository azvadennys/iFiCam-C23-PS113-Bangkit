# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#importing the required libraries
import numpy as np
import os
import time
#importing the VGG16 model on which we wll trsin ourr data
# from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications import MobileNet
from keras.preprocessing import image
# from keras.applications.vgg16 import preprocess_input, decode_predictions
#importing the layes like input layers hidden layers and the  output layers
from keras.layers import Dense, Activation, Flatten
#from keras.layers import merge, Input
from keras.models import Model
from keras.utils import np_utils
from sklearn.utils import shuffle
#importing thee library to split our data in training and testing data
from sklearn.model_selection import train_test_split
# from keras.applications.vgg16 import preprocess_input, decode_predictions
from keras import layers
from keras import Model, Input
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru')

# %%
#bawal putih
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Bawal Putih')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#belato
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Belato')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#Cakalang
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Cakalang')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#gembolo
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Gembolo')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#gole-gole
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Gole Gole')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kakap merah
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kakap Merah')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kembung
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kembung')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kerapu
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kerapu')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#tenggiri
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Tenggiri')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#tuna
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Tuna')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
from pathlib import Path
image_dir = Path('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
import pandas as pd
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(10)
# Out:
#                                             Filepath           Label
# 0  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Kerapu
# 1  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Belato
# 2  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...  Ikan Gole Gole
# 3  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...    Ikan Kembung
# 4  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...  Ikan Gole Gole
# 5  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...   Ikan Tenggiri
# 6  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...   Ikan Cakalang
# 7  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Belato
# 8  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Kerapu
# 9  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...   Ikan Cakalang

# %%
# Display some pictures of the dataset with their labels
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = image_df['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
#Shuffle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Separate in train and test data
train_df, val_df = train_test_split(image_df, train_size=0.8, shuffle=True, random_state=1)

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         seed=0,
                                         target_size=(416,416),
                                         batch_size=16,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                        subset='training',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=val_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         seed=0,
                                         target_size=(416,416),
                                         batch_size=16,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# test_data = test_datagen.flow_from_dataframe(dataframe=test_df,
#                                         x_col='Filepath',
#                                         y_col='Label',
#                                          seed=0,
#                                          target_size=(416,416),
#                                          batch_size=16,
#                                          shuffle=False,
#                                          class_mode = 'categorical',
#                                          )
# Out:
# Found 5520 validated image filenames belonging to 10 classes.
# Found 1380 validated image filenames belonging to 10 classes.

# %% [markdown]
# # Modelling & Training ResNet-50

# %%
from keras import Model, Input
input_shape = (416,416,3)
model_input = Input(shape=input_shape)

# %%
from tensorflow.keras.applications import MobileNetV2
from keras import layers
from keras import Model, Input
from tensorflow.keras.optimizers import Adam

from keras.callbacks import ReduceLROnPlateau, EarlyStopping

import torchvision.models as models
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
# from tensorflow.keras.applications import ResNet50    # underfit
# from tensorflow.keras.applications import ResNet152V2 # overfit
model3 = tf.keras.models.Sequential([
    MobileNetV2(weights="imagenet", include_top=False, input_tensor=model_input),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.GlobalAveragePooling2D(),
    # tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    # tf.keras.layers.Dropout(0.1),
    # tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# model3.layers[0].trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
for layer in model3.layers[:-1]:
    layer.trainable=False

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.1 and logs.get('val_loss') < 0.1):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Tentukan path penyimpanan model
checkpoint_path = '/content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=1)  # Menampilkan pesan saat menyimpan

# %%
callbacks = myCallback()
optimizer = Adam(learning_rate=0.0001)
model3.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 13, 13, 1280)     2257984
#  ional)
#
#  dropout_1 (Dropout)         (None, 13, 13, 1280)      0
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 256)               327936
#
#  dense_6 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 2,588,490
# Trainable params: 2,570
# Non-trainable params: 2,585,920
# _________________________________________________________________

# %%
mobilenetv2_history = model3.fit(
                  train_data,
                  validation_data=validasi_data,
                  steps_per_epoch=train_data.n/16,
                  validation_steps=validasi_data.n/16,
                  epochs=100,
                  callbacks=([callbacks],[checkpoint_callback]))
# Out:
# Epoch 1/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2856 - accuracy: 0.1513
# Epoch 1: loss improved from inf to 2.28565, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 1969s 6s/step - loss: 2.2856 - accuracy: 0.1513 - val_loss: 2.2345 - val_accuracy: 0.1986
# Epoch 2/100
# 345/345 [==============================] - ETA: 0s - loss: 2.1583 - accuracy: 0.2513
# Epoch 2: loss improved from 2.28565 to 2.15825, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 309s 895ms/step - loss: 2.1583 - accuracy: 0.2513 - val_loss: 2.1324 - val_accuracy: 0.2717
# Epoch 3/100
# 345/345 [==============================] - ETA: 0s - loss: 2.0732 - accuracy: 0.3272
# Epoch 3: loss improved from 2.15825 to 2.07322, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 308s 892ms/step - loss: 2.0732 - accuracy: 0.3272 - val_loss: 2.0472 - val_accuracy: 0.3312
# Epoch 4/100
# 345/345 [==============================] - ETA: 0s - loss: 1.9978 - accuracy: 0.3797
# Epoch 4: loss improved from 2.07322 to 1.99779, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 310s 898ms/step - loss: 1.9978 - accuracy: 0.3797 - val_loss: 1.9661 - val_accuracy: 0.3971
# Epoch 5/100
# 345/345 [==============================] - ETA: 0s - loss: 1.9151 - accuracy: 0.4457
# Epoch 5: loss improved from 1.99779 to 1.91514, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 307s 890ms/step - loss: 1.9151 - accuracy: 0.4457 - val_loss: 1.8938 - val_accuracy: 0.4435
# Epoch 6/100
# 345/345 [==============================] - ETA: 0s - loss: 1.8433 - accuracy: 0.4768
# Epoch 6: loss improved from 1.91514 to 1.84326, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 310s 899ms/step - loss: 1.8433 - accuracy: 0.4768 - val_loss: 1.8255 - val_accuracy: 0.4725
# Epoch 7/100
# 345/345 [==============================] - ETA: 0s - loss: 1.7845 - accuracy: 0.5076
# Epoch 7: loss improved from 1.84326 to 1.78448, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 312s 904ms/step - loss: 1.7845 - accuracy: 0.5076 - val_loss: 1.7671 - val_accuracy: 0.5014
# Epoch 8/100
# 345/345 [==============================] - ETA: 0s - loss: 1.7239 - accuracy: 0.5333
# Epoch 8: loss improved from 1.78448 to 1.72395, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 309s 897ms/step - loss: 1.7239 - accuracy: 0.5333 - val_loss: 1.7108 - val_accuracy: 0.5123
# Epoch 9/100
# 345/345 [==============================] - ETA: 0s - loss: 1.6707 - accuracy: 0.5614
# Epoch 9: loss improved from 1.72395 to 1.67066, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 309s 897ms/step - loss: 1.6707 - accuracy: 0.5614 - val_loss: 1.6599 - val_accuracy: 0.5355
# Epoch 10/100
# 345/345 [==============================] - ETA: 0s - loss: 1.6177 - accuracy: 0.5803
# Epoch 10: loss improved from 1.67066 to 1.61770, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 310s 900ms/step - loss: 1.6177 - accuracy: 0.5803 - val_loss: 1.6103 - val_accuracy: 0.5580
# Epoch 11/100
# 345/345 [==============================] - ETA: 0s - loss: 1.5631 - accuracy: 0.6045
# Epoch 11: loss improved from 1.61770 to 1.56311, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 306s 888ms/step - loss: 1.5631 - accuracy: 0.6045 - val_loss: 1.5671 - val_accuracy: 0.5717
# Epoch 12/100
# 345/345 [==============================] - ETA: 0s - loss: 1.5276 - accuracy: 0.6174
# Epoch 12: loss improved from 1.56311 to 1.52758, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 308s 894ms/step - loss: 1.5276 - accuracy: 0.6174 - val_loss: 1.5285 - val_accuracy: 0.5862
# Epoch 13/100
# 345/345 [==============================] - ETA: 0s - loss: 1.4800 - accuracy: 0.6272
# Epoch 13: loss improved from 1.52758 to 1.48002, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 301s 872ms/step - loss: 1.4800 - accuracy: 0.6272 - val_loss: 1.4907 - val_accuracy: 0.6000
# Epoch 14/100
# 345/345 [==============================] - ETA: 0s - loss: 1.4532 - accuracy: 0.6359
# Epoch 14: loss improved from 1.48002 to 1.45319, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 302s 876ms/step - loss: 1.4532 - accuracy: 0.6359 - val_loss: 1.4558 - val_accuracy: 0.6014
# Epoch 15/100
# 345/345 [==============================] - ETA: 0s - loss: 1.4147 - accuracy: 0.6478
# Epoch 15: loss improved from 1.45319 to 1.41467, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 303s 878ms/step - loss: 1.4147 - accuracy: 0.6478 - val_loss: 1.4236 - val_accuracy: 0.6145
# Epoch 16/100
# 345/345 [==============================] - ETA: 0s - loss: 1.3704 - accuracy: 0.6589
# Epoch 16: loss improved from 1.41467 to 1.37044, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 310s 898ms/step - loss: 1.3704 - accuracy: 0.6589 - val_loss: 1.3929 - val_accuracy: 0.6188
# Epoch 17/100
# 345/345 [==============================] - ETA: 0s - loss: 1.3489 - accuracy: 0.6685
# Epoch 17: loss improved from 1.37044 to 1.34893, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 305s 884ms/step - loss: 1.3489 - accuracy: 0.6685 - val_loss: 1.3629 - val_accuracy: 0.6297
# Epoch 18/100
# 345/345 [==============================] - ETA: 0s - loss: 1.3256 - accuracy: 0.6681
# Epoch 18: loss improved from 1.34893 to 1.32564, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 313s 906ms/step - loss: 1.3256 - accuracy: 0.6681 - val_loss: 1.3388 - val_accuracy: 0.6333
# Epoch 19/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2908 - accuracy: 0.6757
# Epoch 19: loss improved from 1.32564 to 1.29079, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 317s 919ms/step - loss: 1.2908 - accuracy: 0.6757 - val_loss: 1.3176 - val_accuracy: 0.6326
# Epoch 20/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2691 - accuracy: 0.6861
# Epoch 20: loss improved from 1.29079 to 1.26914, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 312s 903ms/step - loss: 1.2691 - accuracy: 0.6861 - val_loss: 1.2918 - val_accuracy: 0.6471
# Epoch 21/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2463 - accuracy: 0.6899
# Epoch 21: loss improved from 1.26914 to 1.24627, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 309s 895ms/step - loss: 1.2463 - accuracy: 0.6899 - val_loss: 1.2697 - val_accuracy: 0.6478
# Epoch 22/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2198 - accuracy: 0.6938
# Epoch 22: loss improved from 1.24627 to 1.21977, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 312s 906ms/step - loss: 1.2198 - accuracy: 0.6938 - val_loss: 1.2536 - val_accuracy: 0.6464
# Epoch 23/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2082 - accuracy: 0.6942
# Epoch 23: loss improved from 1.21977 to 1.20822, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 308s 894ms/step - loss: 1.2082 - accuracy: 0.6942 - val_loss: 1.2350 - val_accuracy: 0.6493
# Epoch 24/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1755 - accuracy: 0.7101
# Epoch 24: loss improved from 1.20822 to 1.17548, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 307s 891ms/step - loss: 1.1755 - accuracy: 0.7101 - val_loss: 1.2142 - val_accuracy: 0.6565
# Epoch 25/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1565 - accuracy: 0.7152
# Epoch 25: loss improved from 1.17548 to 1.15648, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 305s 885ms/step - loss: 1.1565 - accuracy: 0.7152 - val_loss: 1.1993 - val_accuracy: 0.6565
# Epoch 26/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1394 - accuracy: 0.7159
# Epoch 26: loss improved from 1.15648 to 1.13937, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 307s 891ms/step - loss: 1.1394 - accuracy: 0.7159 - val_loss: 1.1831 - val_accuracy: 0.6667
# Epoch 27/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1202 - accuracy: 0.7208
# Epoch 27: loss improved from 1.13937 to 1.12017, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 308s 892ms/step - loss: 1.1202 - accuracy: 0.7208 - val_loss: 1.1686 - val_accuracy: 0.6717
# Epoch 28/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1014 - accuracy: 0.7234
# Epoch 28: loss improved from 1.12017 to 1.10136, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 309s 896ms/step - loss: 1.1014 - accuracy: 0.7234 - val_loss: 1.1509 - val_accuracy: 0.6754
# Epoch 29/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0916 - accuracy: 0.7221
# Epoch 29: loss improved from 1.10136 to 1.09163, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 307s 890ms/step - loss: 1.0916 - accuracy: 0.7221 - val_loss: 1.1402 - val_accuracy: 0.6754
# Epoch 30/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0670 - accuracy: 0.7395
# Epoch 30: loss improved from 1.09163 to 1.06696, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 310s 899ms/step - loss: 1.0670 - accuracy: 0.7395 - val_loss: 1.1231 - val_accuracy: 0.6855
# Epoch 31/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0574 - accuracy: 0.7362
# Epoch 31: loss improved from 1.06696 to 1.05741, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 317s 918ms/step - loss: 1.0574 - accuracy: 0.7362 - val_loss: 1.1128 - val_accuracy: 0.6862
# Epoch 32/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0460 - accuracy: 0.7344
# Epoch 32: loss improved from 1.05741 to 1.04597, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 312s 905ms/step - loss: 1.0460 - accuracy: 0.7344 - val_loss: 1.1041 - val_accuracy: 0.6855
# Epoch 33/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0403 - accuracy: 0.7315
# Epoch 33: loss improved from 1.04597 to 1.04026, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 [==============================] - 315s 914ms/step - loss: 1.0403 - accuracy: 0.7315 - val_loss: 1.0925 - val_accuracy: 0.6862
# Epoch 34/100
# 216/345 [=================>............] - ETA: 1:52 - loss: 1.0136 - accuracy: 0.7410

# %%
import tensorflow as tf
# filename="InceptionV3.h5"
# file_path = "/content/drive/MyDrive/bangkit/"
# checkpoint_path = os.path.join(file_path, filename)
checkpoint_path = '/content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5'
model3 = tf.keras.models.load_model(checkpoint_path)

# %%
history3 = model3.fit(train_data,
           validation_data = validasi_data,
           epochs = 20,verbose = 2,
           callbacks=([callbacks],[checkpoint_callback]))
# Out:
# Epoch 1/20
#
# Epoch 1: loss improved from inf to 1.02607, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 - 2075s - loss: 1.0261 - accuracy: 0.7384 - val_loss: 1.0459 - val_accuracy: 0.7043 - 2075s/epoch - 6s/step
# Epoch 2/20
#
# Epoch 2: loss improved from 1.02607 to 1.00166, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 - 704s - loss: 1.0017 - accuracy: 0.7458 - val_loss: 1.0338 - val_accuracy: 0.7065 - 704s/epoch - 2s/step
# Epoch 3/20
#
# Epoch 3: loss improved from 1.00166 to 1.00002, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 - 713s - loss: 1.0000 - accuracy: 0.7364 - val_loss: 1.0291 - val_accuracy: 0.7007 - 713s/epoch - 2s/step
# Epoch 4/20
#
# Epoch 4: loss improved from 1.00002 to 0.98831, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 - 692s - loss: 0.9883 - accuracy: 0.7486 - val_loss: 1.0161 - val_accuracy: 0.7123 - 692s/epoch - 2s/step
# Epoch 5/20
#
# Epoch 5: loss improved from 0.98831 to 0.96895, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-256-0.2.h5
# 345/345 - 719s - loss: 0.9690 - accuracy: 0.7520 - val_loss: 1.0060 - val_accuracy: 0.7094 - 719s/epoch - 2s/step
# Epoch 6/20

# %%
#plotting
import matplotlib.pyplot as plt
def display_training_curves(training, validation, title, subplot):

    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
#display
display_training_curves(
    resnet_history.history['loss'],
    resnet_history.history['val_loss'],
    'loss', 211)
display_training_curves(
    resnet_history.history['accuracy'],
    resnet_history.history['val_accuracy'],
    'accuracy', 212)

# %% [markdown]
# # Evaluation dan Prediction

# %%
# Predict the label of the test_images
import numpy as np
pred = model3.predict(validasi_data)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (validasi_data.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 10 predictions: {pred[:10]}')

# %%
#classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_test = list(val_df.Label)
print(classification_report(y_test, pred))

# %%
import seaborn as sns
import pandas as pd
cm  = confusion_matrix(pred,y_test)
df_cm = pd.DataFrame(cm, index = [i for i in range(10)],
                  columns = [i for i in range(10)])
sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d')
plt.title('confusion matrix')
plt.xlabel('prediction')
plt.ylabel('Actual');

# %%
# Display some pictures of the dataset with their labels and the predictions
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(val_df.Filepath.iloc[i]))
    ax.set_title(f"True: {val_df.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Save Model

# %%
MODEL_BASE_PATH = "/content/drive/MyDrive"
PROJECT_NAME = "Percobaan-ResNet50"
SAVE_MODEL_NAME = "Final100-ResNet-512-01.h5"
save_model_path = os.path.join(MODEL_BASE_PATH, PROJECT_NAME, SAVE_MODEL_NAME)
if os.path.exists(os.path.join(MODEL_BASE_PATH, PROJECT_NAME)) == False:
    os.makedirs(os.path.join(MODEL_BASE_PATH, PROJECT_NAME))

print('Saving Model At {}...'.format(save_model_path))
model3.save(save_model_path,include_optimizer=False)

# %% [markdown]
# # Lanjut Epoch Pake Checkpoint Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import os
os.chdir('C:/Users/ASUS/Dataset')
print(os.getcwd() + "\n")
# Out:
# C:\Users\ASUS\Dataset

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') > 0.96 and logs.get('val_accuracy') > 0.90):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
# Tentukan path penyimpanan model
checkpoint_path = 'C:/Users/ASUS/Dataset/Hasil/Percobaan-Resnet50/model_resnet50-v1.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='val_loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=1)  # Menampilkan pesan saat menyimpan

# %%
callbacks = myCallback()
resnet.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# %%
resnet_history = resnet.fit(train_data,
                            steps_per_epoch=train_data.n/16,
                            epochs=20,
                            validation_data=val_data,
                            validation_steps=val_data.n/16,
                            callbacks=([callbacks],[checkpoint_callback]),
                            verbose = 2
                            )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 resnet_history = resnet.fit(train_data,
#       2                             steps_per_epoch=train_data.n/16,
#       3                             epochs=20,
#       4                             validation_data=val_data,
#       5                             validation_steps=val_data.n/16,
#       6                             callbacks=([callbacks],[checkpoint_callback]),
#       7                             verbose = 2
#       8                             )
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py:1134, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1128   self._cluster_coordinator = tf.distribute.experimental.coordinator.ClusterCoordinator(
#    1129       self.distribute_strategy)
#    1131 with self.distribute_strategy.scope(), \
#    1132      training_utils.RespectCompiledTrainableState(self):
#    1133   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1134   data_handler = data_adapter.get_data_handler(
#    1135       x=x,
#    1136       y=y,
#    1137       sample_weight=sample_weight,
#    1138       batch_size=batch_size,
#    1139       steps_per_epoch=steps_per_epoch,
#    1140       initial_epoch=initial_epoch,
#    1141       epochs=epochs,
#    1142       shuffle=shuffle,
#    1143       class_weight=class_weight,
#    1144       max_queue_size=max_queue_size,
#    1145       workers=workers,
#    1146       use_multiprocessing=use_multiprocessing,
#    1147       model=self,
#    1148       steps_per_execution=self._steps_per_execution)
#    1150   # Container that configures and calls `tf.keras.Callback`s.
#    1151   if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:1383, in get_data_handler(*args, **kwargs)
#    1381 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383 return DataHandler(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:1138, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1135   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1137 adapter_cls = select_data_adapter(x, y)
# -> 1138 self._adapter = adapter_cls(
#    1139     x,
#    1140     y,
#    1141     batch_size=batch_size,
#    1142     steps=steps_per_epoch,
#    1143     epochs=epochs - initial_epoch,
#    1144     sample_weights=sample_weight,
#    1145     shuffle=shuffle,
#    1146     max_queue_size=max_queue_size,
#    1147     workers=workers,
#    1148     use_multiprocessing=use_multiprocessing,
#    1149     distribution_strategy=tf.distribute.get_strategy(),
#    1150     model=model)
#    1152 strategy = tf.distribute.get_strategy()
#    1154 self._current_step = 0
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:917, in KerasSequenceAdapter.__init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     915 self._keras_sequence = x
#     916 self._enqueuer = None
# --> 917 super(KerasSequenceAdapter, self).__init__(
#     918     x,
#     919     shuffle=False,  # Shuffle is handed in the _make_callable override.
#     920     workers=workers,
#     921     use_multiprocessing=use_multiprocessing,
#     922     max_queue_size=max_queue_size,
#     923     model=model,
#     924     **kwargs)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:794, in GeneratorDataAdapter.__init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     790 super(GeneratorDataAdapter, self).__init__(x, y, **kwargs)
#     792 # Since we have to know the dtype of the python generator when we build the
#     793 # dataset, we have to look at a batch to infer the structure.
# --> 794 peek, x = self._peek_and_restore(x)
#     795 peek = self._standardize_batch(peek)
#     796 peek = _process_tensorlike(peek)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:928, in KerasSequenceAdapter._peek_and_restore(x)
#     926 @staticmethod
#     927 def _peek_and_restore(x):
# --> 928   return x[0], x
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\iterator.py:65, in Iterator.__getitem__(self, idx)
#      62     self._set_index_array()
#      63 index_array = self.index_array[self.batch_size * idx:
#      64                                self.batch_size * (idx + 1)]
# ---> 65 return self._get_batches_of_transformed_samples(index_array)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\iterator.py:227, in BatchFromFilesMixin._get_batches_of_transformed_samples(self, index_array)
#     225 filepaths = self.filepaths
#     226 for i, j in enumerate(index_array):
# --> 227     img = load_img(filepaths[j],
#     228                    color_mode=self.color_mode,
#     229                    target_size=self.target_size,
#     230                    interpolation=self.interpolation)
#     231     x = img_to_array(img, data_format=self.data_format)
#     232     # Pillow images should be closed after `load_img`,
#     233     # but not PIL images.
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\utils.py:113, in load_img(path, grayscale, color_mode, target_size, interpolation)
#     110 if pil_image is None:
#     111     raise ImportError('Could not import PIL.Image. '
#     112                       'The use of `load_img` requires PIL.')
# --> 113 with open(path, 'rb') as f:
#     114     img = pil_image.open(io.BytesIO(f.read()))
#     115     if color_mode == 'grayscale':
#     116         # if image is not already an 8-bit, 16-bit or 32-bit grayscale image
#     117         # convert it to an 8-bit grayscale image.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Ikan Kerapu\\IMG_20230519_110110_jpg.rf.6007c179833f9823ca2971290de5382c.jpg'

# %% [markdown]
# # Predict new data

# %%
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#Input Gambar
# %matplotlib inline
uploaded = files.upload()

for fn in uploaded.keys():

  # predicting images
  path = fn
  img = image.load_img(path, target_size=(416,416))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = resnet.predict(images, batch_size=10)
  print(classes)
  if classes[0][0] == 1:
    print('Penyu Hijau')
  elif classes[0][1] == 1:
    print('Penyu Lekang')
  elif classes[0][2] == 1:
    print('Penyu Sisik')
  elif classes[0][3] == 1:
    print('Penyu Tempayan')
