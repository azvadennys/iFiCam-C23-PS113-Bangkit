# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#importing the required libraries
import numpy as np
import os
import time
#importing the VGG16 model on which we wll trsin ourr data
# from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications import resnet50
from keras.preprocessing import image
# from keras.applications.vgg16 import preprocess_input, decode_predictions
#importing the layes like input layers hidden layers and the  output layers
from keras.layers import Dense, Activation, Flatten
#from keras.layers import merge, Input
from keras.models import Model
from keras.utils import np_utils
from sklearn.utils import shuffle
#importing thee library to split our data in training and testing data
from sklearn.model_selection import train_test_split
# from keras.applications.vgg16 import preprocess_input, decode_predictions
from keras import layers
from keras import Model, Input
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru')

# %%
#bawal putih
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Bawal Putih')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#belato
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Belato')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#Cakalang
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Cakalang')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#gembolo
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Gembolo')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#gole-gole
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Gole Gole')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kakap merah
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kakap Merah')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kembung
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kembung')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kerapu
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kerapu')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#tenggiri
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Tenggiri')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#tuna
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Tuna')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
from pathlib import Path
image_dir = Path('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
import pandas as pd
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(10)
# Out:
#                                             Filepath             Label
# 0  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...       Ikan Belato
# 1  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...      Ikan Gembolo
# 2  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...  Ikan Kakap Merah
# 3  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...       Ikan Kerapu
# 4  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Tenggiri
# 5  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...  Ikan Bawal Putih
# 6  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...       Ikan Belato
# 7  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...  Ikan Kakap Merah
# 8  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Cakalang
# 9  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Cakalang

# %%
# Display some pictures of the dataset with their labels
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = image_df['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
#Shuffle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Separate in train and test data
train_df, val_df = train_test_split(image_df, train_size=0.8, shuffle=True, random_state=1)

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         seed=0,
                                         target_size=(416,416),
                                         batch_size=16,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                        subset='training',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=val_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         seed=0,
                                         target_size=(416,416),
                                         batch_size=16,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# test_data = test_datagen.flow_from_dataframe(dataframe=test_df,
#                                         x_col='Filepath',
#                                         y_col='Label',
#                                          seed=0,
#                                          target_size=(416,416),
#                                          batch_size=16,
#                                          shuffle=False,
#                                          class_mode = 'categorical',
#                                          )
# Out:
# Found 5520 validated image filenames belonging to 10 classes.
# Found 1380 validated image filenames belonging to 10 classes.

# %% [markdown]
# # Modelling & Training ResNet-50

# %%
from keras import Model, Input
input_shape = (416,416,3)
model_input = Input(shape=input_shape)

# %%
from tensorflow.keras.applications import VGG16
from keras import layers
from keras import Model, Input
from tensorflow.keras.optimizers import RMSprop

from keras.callbacks import ReduceLROnPlateau, EarlyStopping

import torchvision.models as models
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
# from tensorflow.keras.applications import ResNet50    # underfit
# from tensorflow.keras.applications import ResNet152V2 # overfit
model3 = tf.keras.models.Sequential([
    VGG16(weights="imagenet", include_top=False, input_tensor=model_input),
    tf.keras.layers.Dropout(0.15),
    # tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1024, activation='relu'),
    # tf.keras.layers.Dropout(0.1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# model3.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %%
for layer in model3.layers[:-1]:
    layer.trainable=False

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.1 and logs.get('val_loss') < 0.1):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Tentukan path penyimpanan model
checkpoint_path = '/content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=1)  # Menampilkan pesan saat menyimpan

# %%
callbacks = myCallback()
optimizer = Adam(learning_rate=0.0001)
model3.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 13, 13, 512)       14714688
#
#  dropout (Dropout)           (None, 13, 13, 512)       0
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 1024)              88605696
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dense_1 (Dense)             (None, 256)               262400
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 103,589,450
# Trainable params: 2,570
# Non-trainable params: 103,586,880
# _________________________________________________________________

# %%
vgg16_history = model3.fit(
                  train_data,
                  validation_data=validasi_data,
                  steps_per_epoch=train_data.n/16,
                  validation_steps=validasi_data.n/16,
                  epochs=100,
                  callbacks=([callbacks],[checkpoint_callback]))
# Out:
# Epoch 1/100
# 345/345 [==============================] - ETA: 0s - loss: 2.4164 - accuracy: 0.0958
# Epoch 1: loss improved from inf to 2.41640, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 2702s 8s/step - loss: 2.4164 - accuracy: 0.0958 - val_loss: 2.3354 - val_accuracy: 0.0957
# Epoch 2/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3617 - accuracy: 0.1000
# Epoch 2: loss improved from 2.41640 to 2.36174, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 336s 972ms/step - loss: 2.3617 - accuracy: 0.1000 - val_loss: 2.3286 - val_accuracy: 0.1058
# Epoch 3/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3539 - accuracy: 0.0987
# Epoch 3: loss improved from 2.36174 to 2.35388, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 341s 985ms/step - loss: 2.3539 - accuracy: 0.0987 - val_loss: 2.3218 - val_accuracy: 0.1080
# Epoch 4/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3451 - accuracy: 0.1049
# Epoch 4: loss improved from 2.35388 to 2.34513, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 348s 1s/step - loss: 2.3451 - accuracy: 0.1049 - val_loss: 2.3164 - val_accuracy: 0.1167
# Epoch 5/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3396 - accuracy: 0.1127
# Epoch 5: loss improved from 2.34513 to 2.33963, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 343s 994ms/step - loss: 2.3396 - accuracy: 0.1127 - val_loss: 2.3098 - val_accuracy: 0.1225
# Epoch 6/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3425 - accuracy: 0.1096
# Epoch 6: loss did not improve from 2.33963
# 345/345 [==============================] - 338s 978ms/step - loss: 2.3425 - accuracy: 0.1096 - val_loss: 2.3052 - val_accuracy: 0.1312
# Epoch 7/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3363 - accuracy: 0.1069
# Epoch 7: loss improved from 2.33963 to 2.33626, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 342s 990ms/step - loss: 2.3363 - accuracy: 0.1069 - val_loss: 2.2991 - val_accuracy: 0.1290
# Epoch 8/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3258 - accuracy: 0.1150
# Epoch 8: loss improved from 2.33626 to 2.32579, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 350s 1s/step - loss: 2.3258 - accuracy: 0.1150 - val_loss: 2.2939 - val_accuracy: 0.1442
# Epoch 9/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3171 - accuracy: 0.1163
# Epoch 9: loss improved from 2.32579 to 2.31711, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 343s 994ms/step - loss: 2.3171 - accuracy: 0.1163 - val_loss: 2.2875 - val_accuracy: 0.1435
# Epoch 10/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3180 - accuracy: 0.1185
# Epoch 10: loss did not improve from 2.31711
# 345/345 [==============================] - 336s 974ms/step - loss: 2.3180 - accuracy: 0.1185 - val_loss: 2.2807 - val_accuracy: 0.1500
# Epoch 11/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3082 - accuracy: 0.1284
# Epoch 11: loss improved from 2.31711 to 2.30816, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 339s 984ms/step - loss: 2.3082 - accuracy: 0.1284 - val_loss: 2.2744 - val_accuracy: 0.1543
# Epoch 12/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3075 - accuracy: 0.1246
# Epoch 12: loss improved from 2.30816 to 2.30751, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 347s 1s/step - loss: 2.3075 - accuracy: 0.1246 - val_loss: 2.2713 - val_accuracy: 0.1775
# Epoch 13/100
# 345/345 [==============================] - ETA: 0s - loss: 2.3081 - accuracy: 0.1266
# Epoch 13: loss did not improve from 2.30751
# 345/345 [==============================] - 338s 979ms/step - loss: 2.3081 - accuracy: 0.1266 - val_loss: 2.2657 - val_accuracy: 0.1681
# Epoch 14/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2964 - accuracy: 0.1312
# Epoch 14: loss improved from 2.30751 to 2.29638, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 347s 1s/step - loss: 2.2964 - accuracy: 0.1312 - val_loss: 2.2618 - val_accuracy: 0.1681
# Epoch 15/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2897 - accuracy: 0.1355
# Epoch 15: loss improved from 2.29638 to 2.28972, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 342s 990ms/step - loss: 2.2897 - accuracy: 0.1355 - val_loss: 2.2555 - val_accuracy: 0.1775
# Epoch 16/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2862 - accuracy: 0.1377
# Epoch 16: loss improved from 2.28972 to 2.28618, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 340s 986ms/step - loss: 2.2862 - accuracy: 0.1377 - val_loss: 2.2515 - val_accuracy: 0.1826
# Epoch 17/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2860 - accuracy: 0.1377
# Epoch 17: loss improved from 2.28618 to 2.28601, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 335s 972ms/step - loss: 2.2860 - accuracy: 0.1377 - val_loss: 2.2471 - val_accuracy: 0.1855
# Epoch 18/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2778 - accuracy: 0.1402
# Epoch 18: loss improved from 2.28601 to 2.27775, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 338s 978ms/step - loss: 2.2778 - accuracy: 0.1402 - val_loss: 2.2420 - val_accuracy: 0.1920
# Epoch 19/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2797 - accuracy: 0.1357
# Epoch 19: loss did not improve from 2.27775
# 345/345 [==============================] - 334s 969ms/step - loss: 2.2797 - accuracy: 0.1357 - val_loss: 2.2393 - val_accuracy: 0.1884
# Epoch 20/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2708 - accuracy: 0.1458
# Epoch 20: loss improved from 2.27775 to 2.27081, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 338s 981ms/step - loss: 2.2708 - accuracy: 0.1458 - val_loss: 2.2334 - val_accuracy: 0.1986
# Epoch 21/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2707 - accuracy: 0.1498
# Epoch 21: loss improved from 2.27081 to 2.27072, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 359s 1s/step - loss: 2.2707 - accuracy: 0.1498 - val_loss: 2.2301 - val_accuracy: 0.1978
# Epoch 22/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2667 - accuracy: 0.1493
# Epoch 22: loss improved from 2.27072 to 2.26672, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 335s 969ms/step - loss: 2.2667 - accuracy: 0.1493 - val_loss: 2.2256 - val_accuracy: 0.2109
# Epoch 23/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2670 - accuracy: 0.1569
# Epoch 23: loss did not improve from 2.26672
# 345/345 [==============================] - 333s 963ms/step - loss: 2.2670 - accuracy: 0.1569 - val_loss: 2.2220 - val_accuracy: 0.2094
# Epoch 24/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2593 - accuracy: 0.1614
# Epoch 24: loss improved from 2.26672 to 2.25934, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 334s 967ms/step - loss: 2.2593 - accuracy: 0.1614 - val_loss: 2.2146 - val_accuracy: 0.2159
# Epoch 25/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2602 - accuracy: 0.1542
# Epoch 25: loss did not improve from 2.25934
# 345/345 [==============================] - 333s 964ms/step - loss: 2.2602 - accuracy: 0.1542 - val_loss: 2.2126 - val_accuracy: 0.2167
# Epoch 26/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2536 - accuracy: 0.1665
# Epoch 26: loss improved from 2.25934 to 2.25361, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 337s 978ms/step - loss: 2.2536 - accuracy: 0.1665 - val_loss: 2.2093 - val_accuracy: 0.2254
# Epoch 27/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2547 - accuracy: 0.1656
# Epoch 27: loss did not improve from 2.25361
# 345/345 [==============================] - 330s 956ms/step - loss: 2.2547 - accuracy: 0.1656 - val_loss: 2.2046 - val_accuracy: 0.2210
# Epoch 28/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2484 - accuracy: 0.1674
# Epoch 28: loss improved from 2.25361 to 2.24837, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 335s 972ms/step - loss: 2.2484 - accuracy: 0.1674 - val_loss: 2.2020 - val_accuracy: 0.2210
# Epoch 29/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2484 - accuracy: 0.1656
# Epoch 29: loss did not improve from 2.24837
# 345/345 [==============================] - 328s 950ms/step - loss: 2.2484 - accuracy: 0.1656 - val_loss: 2.1994 - val_accuracy: 0.2319
# Epoch 30/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2357 - accuracy: 0.1766
# Epoch 30: loss improved from 2.24837 to 2.23566, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 332s 963ms/step - loss: 2.2357 - accuracy: 0.1766 - val_loss: 2.1949 - val_accuracy: 0.2275
# Epoch 31/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2398 - accuracy: 0.1728
# Epoch 31: loss did not improve from 2.23566
# 345/345 [==============================] - 330s 954ms/step - loss: 2.2398 - accuracy: 0.1728 - val_loss: 2.1919 - val_accuracy: 0.2304
# Epoch 32/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2429 - accuracy: 0.1736
# Epoch 32: loss did not improve from 2.23566
# 345/345 [==============================] - 330s 957ms/step - loss: 2.2429 - accuracy: 0.1736 - val_loss: 2.1878 - val_accuracy: 0.2391
# Epoch 33/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2347 - accuracy: 0.1766
# Epoch 33: loss improved from 2.23566 to 2.23472, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 339s 982ms/step - loss: 2.2347 - accuracy: 0.1766 - val_loss: 2.1819 - val_accuracy: 0.2551
# Epoch 34/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2339 - accuracy: 0.1781
# Epoch 34: loss improved from 2.23472 to 2.23386, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 334s 969ms/step - loss: 2.2339 - accuracy: 0.1781 - val_loss: 2.1794 - val_accuracy: 0.2500
# Epoch 35/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2298 - accuracy: 0.1842
# Epoch 35: loss improved from 2.23386 to 2.22975, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 364s 1s/step - loss: 2.2298 - accuracy: 0.1842 - val_loss: 2.1760 - val_accuracy: 0.2500
# Epoch 36/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2283 - accuracy: 0.1746
# Epoch 36: loss improved from 2.22975 to 2.22827, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 330s 957ms/step - loss: 2.2283 - accuracy: 0.1746 - val_loss: 2.1740 - val_accuracy: 0.2493
# Epoch 37/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2240 - accuracy: 0.1889
# Epoch 37: loss improved from 2.22827 to 2.22398, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 338s 980ms/step - loss: 2.2240 - accuracy: 0.1889 - val_loss: 2.1700 - val_accuracy: 0.2536
# Epoch 38/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2213 - accuracy: 0.1866
# Epoch 38: loss improved from 2.22398 to 2.22133, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 341s 989ms/step - loss: 2.2213 - accuracy: 0.1866 - val_loss: 2.1676 - val_accuracy: 0.2457
# Epoch 39/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2216 - accuracy: 0.1844
# Epoch 39: loss did not improve from 2.22133
# 345/345 [==============================] - 334s 969ms/step - loss: 2.2216 - accuracy: 0.1844 - val_loss: 2.1659 - val_accuracy: 0.2486
# Epoch 40/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2330 - accuracy: 0.1808
# Epoch 40: loss did not improve from 2.22133
# 345/345 [==============================] - 331s 961ms/step - loss: 2.2330 - accuracy: 0.1808 - val_loss: 2.1607 - val_accuracy: 0.2594
# Epoch 41/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2137 - accuracy: 0.1888
# Epoch 41: loss improved from 2.22133 to 2.21373, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 338s 979ms/step - loss: 2.2137 - accuracy: 0.1888 - val_loss: 2.1595 - val_accuracy: 0.2601
# Epoch 42/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2119 - accuracy: 0.1991
# Epoch 42: loss improved from 2.21373 to 2.21194, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 342s 990ms/step - loss: 2.2119 - accuracy: 0.1991 - val_loss: 2.1558 - val_accuracy: 0.2659
# Epoch 43/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2073 - accuracy: 0.1964
# Epoch 43: loss improved from 2.21194 to 2.20733, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 342s 990ms/step - loss: 2.2073 - accuracy: 0.1964 - val_loss: 2.1537 - val_accuracy: 0.2667
# Epoch 44/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2090 - accuracy: 0.1909
# Epoch 44: loss did not improve from 2.20733
# 345/345 [==============================] - 329s 953ms/step - loss: 2.2090 - accuracy: 0.1909 - val_loss: 2.1495 - val_accuracy: 0.2739
# Epoch 45/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2058 - accuracy: 0.1982
# Epoch 45: loss improved from 2.20733 to 2.20584, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 336s 975ms/step - loss: 2.2058 - accuracy: 0.1982 - val_loss: 2.1478 - val_accuracy: 0.2710
# Epoch 46/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2008 - accuracy: 0.2024
# Epoch 46: loss improved from 2.20584 to 2.20084, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-VGG16/VGG16-512-01.h5
# 345/345 [==============================] - 337s 978ms/step - loss: 2.2008 - accuracy: 0.2024 - val_loss: 2.1448 - val_accuracy: 0.2725
# Epoch 47/100
#  42/345 [==>...........................] - ETA: 4:35 - loss: 2.1967 - accuracy: 0.1994

# %%
#plotting
import matplotlib.pyplot as plt
def display_training_curves(training, validation, title, subplot):

    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
#display
display_training_curves(
    resnet_history.history['loss'],
    resnet_history.history['val_loss'],
    'loss', 211)
display_training_curves(
    resnet_history.history['accuracy'],
    resnet_history.history['val_accuracy'],
    'accuracy', 212)

# %% [markdown]
# # Evaluation dan Prediction

# %%
# Predict the label of the test_images
import numpy as np
pred = model3.predict(validasi_data)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (validasi_data.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 10 predictions: {pred[:10]}')

# %%
#classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_test = list(val_df.Label)
print(classification_report(y_test, pred))

# %%
import seaborn as sns
import pandas as pd
cm  = confusion_matrix(pred,y_test)
df_cm = pd.DataFrame(cm, index = [i for i in range(10)],
                  columns = [i for i in range(10)])
sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d')
plt.title('confusion matrix')
plt.xlabel('prediction')
plt.ylabel('Actual');

# %%
# Display some pictures of the dataset with their labels and the predictions
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(val_df.Filepath.iloc[i]))
    ax.set_title(f"True: {val_df.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Save Model

# %%
MODEL_BASE_PATH = "/content/drive/MyDrive"
PROJECT_NAME = "Percobaan-ResNet50"
SAVE_MODEL_NAME = "Final100-ResNet-512-01.h5"
save_model_path = os.path.join(MODEL_BASE_PATH, PROJECT_NAME, SAVE_MODEL_NAME)
if os.path.exists(os.path.join(MODEL_BASE_PATH, PROJECT_NAME)) == False:
    os.makedirs(os.path.join(MODEL_BASE_PATH, PROJECT_NAME))

print('Saving Model At {}...'.format(save_model_path))
model3.save(save_model_path,include_optimizer=False)

# %% [markdown]
# # Lanjut Epoch Pake Checkpoint Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import os
os.chdir('C:/Users/ASUS/Dataset')
print(os.getcwd() + "\n")
# Out:
# C:\Users\ASUS\Dataset

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') > 0.96 and logs.get('val_accuracy') > 0.90):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
# Tentukan path penyimpanan model
checkpoint_path = 'C:/Users/ASUS/Dataset/Hasil/Percobaan-Resnet50/model_resnet50-v1.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='val_loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=1)  # Menampilkan pesan saat menyimpan

# %%
callbacks = myCallback()
resnet.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# %%
resnet_history = resnet.fit(train_data,
                            steps_per_epoch=train_data.n/16,
                            epochs=20,
                            validation_data=val_data,
                            validation_steps=val_data.n/16,
                            callbacks=([callbacks],[checkpoint_callback]),
                            verbose = 2
                            )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 resnet_history = resnet.fit(train_data,
#       2                             steps_per_epoch=train_data.n/16,
#       3                             epochs=20,
#       4                             validation_data=val_data,
#       5                             validation_steps=val_data.n/16,
#       6                             callbacks=([callbacks],[checkpoint_callback]),
#       7                             verbose = 2
#       8                             )
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py:1134, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1128   self._cluster_coordinator = tf.distribute.experimental.coordinator.ClusterCoordinator(
#    1129       self.distribute_strategy)
#    1131 with self.distribute_strategy.scope(), \
#    1132      training_utils.RespectCompiledTrainableState(self):
#    1133   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1134   data_handler = data_adapter.get_data_handler(
#    1135       x=x,
#    1136       y=y,
#    1137       sample_weight=sample_weight,
#    1138       batch_size=batch_size,
#    1139       steps_per_epoch=steps_per_epoch,
#    1140       initial_epoch=initial_epoch,
#    1141       epochs=epochs,
#    1142       shuffle=shuffle,
#    1143       class_weight=class_weight,
#    1144       max_queue_size=max_queue_size,
#    1145       workers=workers,
#    1146       use_multiprocessing=use_multiprocessing,
#    1147       model=self,
#    1148       steps_per_execution=self._steps_per_execution)
#    1150   # Container that configures and calls `tf.keras.Callback`s.
#    1151   if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:1383, in get_data_handler(*args, **kwargs)
#    1381 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383 return DataHandler(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:1138, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1135   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1137 adapter_cls = select_data_adapter(x, y)
# -> 1138 self._adapter = adapter_cls(
#    1139     x,
#    1140     y,
#    1141     batch_size=batch_size,
#    1142     steps=steps_per_epoch,
#    1143     epochs=epochs - initial_epoch,
#    1144     sample_weights=sample_weight,
#    1145     shuffle=shuffle,
#    1146     max_queue_size=max_queue_size,
#    1147     workers=workers,
#    1148     use_multiprocessing=use_multiprocessing,
#    1149     distribution_strategy=tf.distribute.get_strategy(),
#    1150     model=model)
#    1152 strategy = tf.distribute.get_strategy()
#    1154 self._current_step = 0
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:917, in KerasSequenceAdapter.__init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     915 self._keras_sequence = x
#     916 self._enqueuer = None
# --> 917 super(KerasSequenceAdapter, self).__init__(
#     918     x,
#     919     shuffle=False,  # Shuffle is handed in the _make_callable override.
#     920     workers=workers,
#     921     use_multiprocessing=use_multiprocessing,
#     922     max_queue_size=max_queue_size,
#     923     model=model,
#     924     **kwargs)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:794, in GeneratorDataAdapter.__init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     790 super(GeneratorDataAdapter, self).__init__(x, y, **kwargs)
#     792 # Since we have to know the dtype of the python generator when we build the
#     793 # dataset, we have to look at a batch to infer the structure.
# --> 794 peek, x = self._peek_and_restore(x)
#     795 peek = self._standardize_batch(peek)
#     796 peek = _process_tensorlike(peek)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:928, in KerasSequenceAdapter._peek_and_restore(x)
#     926 @staticmethod
#     927 def _peek_and_restore(x):
# --> 928   return x[0], x
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\iterator.py:65, in Iterator.__getitem__(self, idx)
#      62     self._set_index_array()
#      63 index_array = self.index_array[self.batch_size * idx:
#      64                                self.batch_size * (idx + 1)]
# ---> 65 return self._get_batches_of_transformed_samples(index_array)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\iterator.py:227, in BatchFromFilesMixin._get_batches_of_transformed_samples(self, index_array)
#     225 filepaths = self.filepaths
#     226 for i, j in enumerate(index_array):
# --> 227     img = load_img(filepaths[j],
#     228                    color_mode=self.color_mode,
#     229                    target_size=self.target_size,
#     230                    interpolation=self.interpolation)
#     231     x = img_to_array(img, data_format=self.data_format)
#     232     # Pillow images should be closed after `load_img`,
#     233     # but not PIL images.
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\utils.py:113, in load_img(path, grayscale, color_mode, target_size, interpolation)
#     110 if pil_image is None:
#     111     raise ImportError('Could not import PIL.Image. '
#     112                       'The use of `load_img` requires PIL.')
# --> 113 with open(path, 'rb') as f:
#     114     img = pil_image.open(io.BytesIO(f.read()))
#     115     if color_mode == 'grayscale':
#     116         # if image is not already an 8-bit, 16-bit or 32-bit grayscale image
#     117         # convert it to an 8-bit grayscale image.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Ikan Kerapu\\IMG_20230519_110110_jpg.rf.6007c179833f9823ca2971290de5382c.jpg'

# %% [markdown]
# # Predict new data

# %%
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#Input Gambar
# %matplotlib inline
uploaded = files.upload()

for fn in uploaded.keys():

  # predicting images
  path = fn
  img = image.load_img(path, target_size=(416,416))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = resnet.predict(images, batch_size=10)
  print(classes)
  if classes[0][0] == 1:
    print('Penyu Hijau')
  elif classes[0][1] == 1:
    print('Penyu Lekang')
  elif classes[0][2] == 1:
    print('Penyu Sisik')
  elif classes[0][3] == 1:
    print('Penyu Tempayan')
