# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#importing the required libraries
import numpy as np
import os
import time
#importing the VGG16 model on which we wll trsin ourr data
# from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications import MobileNet
from keras.preprocessing import image
# from keras.applications.vgg16 import preprocess_input, decode_predictions
#importing the layes like input layers hidden layers and the  output layers
from keras.layers import Dense, Activation, Flatten
#from keras.layers import merge, Input
from keras.models import Model
from keras.utils import np_utils
from sklearn.utils import shuffle
#importing thee library to split our data in training and testing data
from sklearn.model_selection import train_test_split
# from keras.applications.vgg16 import preprocess_input, decode_predictions
from keras import layers
from keras import Model, Input
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru')

# %%
#bawal putih
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Bawal Putih')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#belato
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Belato')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#Cakalang
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Cakalang')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#gembolo
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Gembolo')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#gole-gole
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Gole Gole')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kakap merah
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kakap Merah')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kembung
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kembung')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#kerapu
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Kerapu')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#tenggiri
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Tenggiri')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#tuna
import os
folder_path = ('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train/Ikan Tuna')
test = os.listdir(folder_path)
for fichier in test:
    if not(fichier.endswith(".jpg")):
        os.remove(os.path.join(folder_path, fichier))

# %%
#cek label
from pathlib import Path
image_dir = Path('/content/drive/MyDrive/BANGKIT 2023/Data_Ikan_Baru/train')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.jpg'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
import pandas as pd
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(10)
# Out:
#                                             Filepath             Label
# 0  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Cakalang
# 1  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...    Ikan Gole Gole
# 2  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...       Ikan Belato
# 3  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...       Ikan Kerapu
# 4  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...  Ikan Bawal Putih
# 5  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Cakalang
# 6  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Cakalang
# 7  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...      Ikan Gembolo
# 8  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...  Ikan Kakap Merah
# 9  /content/drive/MyDrive/BANGKIT 2023/Data_Ikan_...     Ikan Cakalang

# %%
# Display some pictures of the dataset with their labels
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Display the number of pictures of each category
import seaborn as sns
vc = image_df['Label'].value_counts()
plt.figure(figsize=(20,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
#Shuffle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
# Separate in train and test data
train_df, val_df = train_test_split(image_df, train_size=0.8, shuffle=True, random_state=1)

# %%
#data generator
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_dataframe(dataframe=train_df,
                                          x_col='Filepath',
                                          y_col='Label',
                                         seed=0,
                                         target_size=(416,416),
                                         batch_size=16,
                                         shuffle=True,
                                         class_mode = 'categorical',
                                        subset='training',
                                         )

validasi_data = val_datagen.flow_from_dataframe(dataframe=val_df,
                                        x_col='Filepath',
                                        y_col='Label',
                                         seed=0,
                                         target_size=(416,416),
                                         batch_size=16,
                                         shuffle=False,
                                         class_mode = 'categorical',
                                         )
# test_data = test_datagen.flow_from_dataframe(dataframe=test_df,
#                                         x_col='Filepath',
#                                         y_col='Label',
#                                          seed=0,
#                                          target_size=(416,416),
#                                          batch_size=16,
#                                          shuffle=False,
#                                          class_mode = 'categorical',
#                                          )
# Out:
# Found 5520 validated image filenames belonging to 10 classes.
# Found 1380 validated image filenames belonging to 10 classes.

# %% [markdown]
# # Modelling & Training ResNet-50

# %%
from keras import Model, Input
input_shape = (416,416,3)
model_input = Input(shape=input_shape)

# %%
from tensorflow.keras.applications import MobileNetV2
from keras import layers
from keras import Model, Input
from tensorflow.keras.optimizers import Adam

from keras.callbacks import ReduceLROnPlateau, EarlyStopping

import torchvision.models as models
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
# from tensorflow.keras.applications import ResNet50    # underfit
# from tensorflow.keras.applications import ResNet152V2 # overfit
model3 = tf.keras.models.Sequential([
    MobileNetV2(weights="imagenet", include_top=False, input_tensor=model_input),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.GlobalAveragePooling2D(),
    # tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# model3.layers[0].trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
for layer in model3.layers[:-1]:
    layer.trainable=False

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.1 and logs.get('val_loss') < 0.1):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Tentukan path penyimpanan model
checkpoint_path = '/content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=1)  # Menampilkan pesan saat menyimpan

# %%
callbacks = myCallback()
optimizer = Adam(learning_rate=0.0001)
model3.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 13, 13, 1280)     2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              1311744
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4,099,658
# Trainable params: 5,130
# Non-trainable params: 4,094,528
# _________________________________________________________________

# %%
mobilenetv2_history = model3.fit(
                  train_data,
                  validation_data=validasi_data,
                  steps_per_epoch=train_data.n/16,
                  validation_steps=validasi_data.n/16,
                  epochs=100,
                  callbacks=([callbacks],[checkpoint_callback]))
# Out:
# Epoch 1/100
# 345/345 [==============================] - ETA: 0s - loss: 2.2918 - accuracy: 0.1293
# Epoch 1: loss improved from inf to 2.29176, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 4746s 14s/step - loss: 2.2918 - accuracy: 0.1293 - val_loss: 2.2139 - val_accuracy: 0.2000
# Epoch 2/100
# 345/345 [==============================] - ETA: 0s - loss: 2.1903 - accuracy: 0.2281
# Epoch 2: loss improved from 2.29176 to 2.19026, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 315s 912ms/step - loss: 2.1903 - accuracy: 0.2281 - val_loss: 2.1227 - val_accuracy: 0.3145
# Epoch 3/100
# 345/345 [==============================] - ETA: 0s - loss: 2.1026 - accuracy: 0.3250
# Epoch 3: loss improved from 2.19026 to 2.10264, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 313s 908ms/step - loss: 2.1026 - accuracy: 0.3250 - val_loss: 2.0382 - val_accuracy: 0.4080
# Epoch 4/100
# 345/345 [==============================] - ETA: 0s - loss: 2.0162 - accuracy: 0.4149
# Epoch 4: loss improved from 2.10264 to 2.01623, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 308s 892ms/step - loss: 2.0162 - accuracy: 0.4149 - val_loss: 1.9602 - val_accuracy: 0.4645
# Epoch 5/100
# 345/345 [==============================] - ETA: 0s - loss: 1.9409 - accuracy: 0.4732
# Epoch 5: loss improved from 2.01623 to 1.94092, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 306s 888ms/step - loss: 1.9409 - accuracy: 0.4732 - val_loss: 1.8910 - val_accuracy: 0.5123
# Epoch 6/100
# 345/345 [==============================] - ETA: 0s - loss: 1.8735 - accuracy: 0.5074
# Epoch 6: loss improved from 1.94092 to 1.87347, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 308s 893ms/step - loss: 1.8735 - accuracy: 0.5074 - val_loss: 1.8251 - val_accuracy: 0.5442
# Epoch 7/100
# 345/345 [==============================] - ETA: 0s - loss: 1.8161 - accuracy: 0.5290
# Epoch 7: loss improved from 1.87347 to 1.81612, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 309s 896ms/step - loss: 1.8161 - accuracy: 0.5290 - val_loss: 1.7643 - val_accuracy: 0.5775
# Epoch 8/100
# 345/345 [==============================] - ETA: 0s - loss: 1.7492 - accuracy: 0.5761
# Epoch 8: loss improved from 1.81612 to 1.74922, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 306s 887ms/step - loss: 1.7492 - accuracy: 0.5761 - val_loss: 1.7093 - val_accuracy: 0.6029
# Epoch 9/100
# 345/345 [==============================] - ETA: 0s - loss: 1.7032 - accuracy: 0.5806
# Epoch 9: loss improved from 1.74922 to 1.70320, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 313s 906ms/step - loss: 1.7032 - accuracy: 0.5806 - val_loss: 1.6585 - val_accuracy: 0.6094
# Epoch 10/100
# 345/345 [==============================] - ETA: 0s - loss: 1.6508 - accuracy: 0.5944
# Epoch 10: loss improved from 1.70320 to 1.65080, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 316s 917ms/step - loss: 1.6508 - accuracy: 0.5944 - val_loss: 1.6138 - val_accuracy: 0.6203
# Epoch 11/100
# 345/345 [==============================] - ETA: 0s - loss: 1.6036 - accuracy: 0.6109
# Epoch 11: loss improved from 1.65080 to 1.60356, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 317s 918ms/step - loss: 1.6036 - accuracy: 0.6109 - val_loss: 1.5697 - val_accuracy: 0.6341
# Epoch 12/100
# 345/345 [==============================] - ETA: 0s - loss: 1.5580 - accuracy: 0.6391
# Epoch 12: loss improved from 1.60356 to 1.55800, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 306s 887ms/step - loss: 1.5580 - accuracy: 0.6391 - val_loss: 1.5296 - val_accuracy: 0.6391
# Epoch 13/100
# 345/345 [==============================] - ETA: 0s - loss: 1.5200 - accuracy: 0.6277
# Epoch 13: loss improved from 1.55800 to 1.51997, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 305s 884ms/step - loss: 1.5200 - accuracy: 0.6277 - val_loss: 1.4911 - val_accuracy: 0.6514
# Epoch 14/100
# 345/345 [==============================] - ETA: 0s - loss: 1.4804 - accuracy: 0.6467
# Epoch 14: loss improved from 1.51997 to 1.48039, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 308s 892ms/step - loss: 1.4804 - accuracy: 0.6467 - val_loss: 1.4559 - val_accuracy: 0.6587
# Epoch 15/100
# 345/345 [==============================] - ETA: 0s - loss: 1.4528 - accuracy: 0.6493
# Epoch 15: loss improved from 1.48039 to 1.45283, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 315s 913ms/step - loss: 1.4528 - accuracy: 0.6493 - val_loss: 1.4239 - val_accuracy: 0.6630
# Epoch 16/100
# 345/345 [==============================] - ETA: 0s - loss: 1.4180 - accuracy: 0.6576
# Epoch 16: loss improved from 1.45283 to 1.41798, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 313s 907ms/step - loss: 1.4180 - accuracy: 0.6576 - val_loss: 1.3949 - val_accuracy: 0.6616
# Epoch 17/100
# 345/345 [==============================] - ETA: 0s - loss: 1.3843 - accuracy: 0.6743
# Epoch 17: loss improved from 1.41798 to 1.38425, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 313s 909ms/step - loss: 1.3843 - accuracy: 0.6743 - val_loss: 1.3660 - val_accuracy: 0.6674
# Epoch 18/100
# 345/345 [==============================] - ETA: 0s - loss: 1.3579 - accuracy: 0.6668
# Epoch 18: loss improved from 1.38425 to 1.35791, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 314s 911ms/step - loss: 1.3579 - accuracy: 0.6668 - val_loss: 1.3391 - val_accuracy: 0.6775
# Epoch 19/100
# 345/345 [==============================] - ETA: 0s - loss: 1.3295 - accuracy: 0.6708
# Epoch 19: loss improved from 1.35791 to 1.32950, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 313s 907ms/step - loss: 1.3295 - accuracy: 0.6708 - val_loss: 1.3168 - val_accuracy: 0.6703
# Epoch 20/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2974 - accuracy: 0.6871
# Epoch 20: loss improved from 1.32950 to 1.29741, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 303s 877ms/step - loss: 1.2974 - accuracy: 0.6871 - val_loss: 1.2918 - val_accuracy: 0.6804
# Epoch 21/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2851 - accuracy: 0.6757
# Epoch 21: loss improved from 1.29741 to 1.28509, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 304s 881ms/step - loss: 1.2851 - accuracy: 0.6757 - val_loss: 1.2688 - val_accuracy: 0.6833
# Epoch 22/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2532 - accuracy: 0.6918
# Epoch 22: loss improved from 1.28509 to 1.25323, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 309s 896ms/step - loss: 1.2532 - accuracy: 0.6918 - val_loss: 1.2484 - val_accuracy: 0.6891
# Epoch 23/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2387 - accuracy: 0.6891
# Epoch 23: loss improved from 1.25323 to 1.23873, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 305s 883ms/step - loss: 1.2387 - accuracy: 0.6891 - val_loss: 1.2312 - val_accuracy: 0.6819
# Epoch 24/100
# 345/345 [==============================] - ETA: 0s - loss: 1.2190 - accuracy: 0.6973
# Epoch 24: loss improved from 1.23873 to 1.21898, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 304s 881ms/step - loss: 1.2190 - accuracy: 0.6973 - val_loss: 1.2103 - val_accuracy: 0.6971
# Epoch 25/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1941 - accuracy: 0.7060
# Epoch 25: loss improved from 1.21898 to 1.19411, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 303s 879ms/step - loss: 1.1941 - accuracy: 0.7060 - val_loss: 1.1905 - val_accuracy: 0.6993
# Epoch 26/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1772 - accuracy: 0.7069
# Epoch 26: loss improved from 1.19411 to 1.17718, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 307s 889ms/step - loss: 1.1772 - accuracy: 0.7069 - val_loss: 1.1768 - val_accuracy: 0.7000
# Epoch 27/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1622 - accuracy: 0.6984
# Epoch 27: loss improved from 1.17718 to 1.16224, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 301s 873ms/step - loss: 1.1622 - accuracy: 0.6984 - val_loss: 1.1576 - val_accuracy: 0.7065
# Epoch 28/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1518 - accuracy: 0.7018
# Epoch 28: loss improved from 1.16224 to 1.15181, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 300s 871ms/step - loss: 1.1518 - accuracy: 0.7018 - val_loss: 1.1454 - val_accuracy: 0.7043
# Epoch 29/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1356 - accuracy: 0.7083
# Epoch 29: loss improved from 1.15181 to 1.13561, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 308s 893ms/step - loss: 1.1356 - accuracy: 0.7083 - val_loss: 1.1306 - val_accuracy: 0.7051
# Epoch 30/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1198 - accuracy: 0.7080
# Epoch 30: loss improved from 1.13561 to 1.11978, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 305s 883ms/step - loss: 1.1198 - accuracy: 0.7080 - val_loss: 1.1165 - val_accuracy: 0.7109
# Epoch 31/100
# 345/345 [==============================] - ETA: 0s - loss: 1.1090 - accuracy: 0.7114
# Epoch 31: loss improved from 1.11978 to 1.10895, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 303s 878ms/step - loss: 1.1090 - accuracy: 0.7114 - val_loss: 1.1017 - val_accuracy: 0.7130
# Epoch 32/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0949 - accuracy: 0.7092
# Epoch 32: loss improved from 1.10895 to 1.09489, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 301s 873ms/step - loss: 1.0949 - accuracy: 0.7092 - val_loss: 1.0898 - val_accuracy: 0.7123
# Epoch 33/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0790 - accuracy: 0.7183
# Epoch 33: loss improved from 1.09489 to 1.07904, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 305s 885ms/step - loss: 1.0790 - accuracy: 0.7183 - val_loss: 1.0773 - val_accuracy: 0.7181
# Epoch 34/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0727 - accuracy: 0.7241
# Epoch 34: loss improved from 1.07904 to 1.07269, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 306s 885ms/step - loss: 1.0727 - accuracy: 0.7241 - val_loss: 1.0642 - val_accuracy: 0.7210
# Epoch 35/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0470 - accuracy: 0.7243
# Epoch 35: loss improved from 1.07269 to 1.04703, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 303s 878ms/step - loss: 1.0470 - accuracy: 0.7243 - val_loss: 1.0562 - val_accuracy: 0.7196
# Epoch 36/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0429 - accuracy: 0.7274
# Epoch 36: loss improved from 1.04703 to 1.04291, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 303s 878ms/step - loss: 1.0429 - accuracy: 0.7274 - val_loss: 1.0439 - val_accuracy: 0.7217
# Epoch 37/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0291 - accuracy: 0.7255
# Epoch 37: loss improved from 1.04291 to 1.02914, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 305s 884ms/step - loss: 1.0291 - accuracy: 0.7255 - val_loss: 1.0365 - val_accuracy: 0.7261
# Epoch 38/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0209 - accuracy: 0.7324
# Epoch 38: loss improved from 1.02914 to 1.02093, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 303s 877ms/step - loss: 1.0209 - accuracy: 0.7324 - val_loss: 1.0234 - val_accuracy: 0.7290
# Epoch 39/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0163 - accuracy: 0.7237
# Epoch 39: loss improved from 1.02093 to 1.01634, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 303s 878ms/step - loss: 1.0163 - accuracy: 0.7237 - val_loss: 1.0171 - val_accuracy: 0.7254
# Epoch 40/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0020 - accuracy: 0.7322
# Epoch 40: loss improved from 1.01634 to 1.00201, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 302s 876ms/step - loss: 1.0020 - accuracy: 0.7322 - val_loss: 1.0086 - val_accuracy: 0.7348
# Epoch 41/100
# 345/345 [==============================] - ETA: 0s - loss: 1.0085 - accuracy: 0.7264
# Epoch 41: loss did not improve from 1.00201
# 345/345 [==============================] - 300s 869ms/step - loss: 1.0085 - accuracy: 0.7264 - val_loss: 0.9990 - val_accuracy: 0.7283
# Epoch 42/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9892 - accuracy: 0.7274
# Epoch 42: loss improved from 1.00201 to 0.98917, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 300s 868ms/step - loss: 0.9892 - accuracy: 0.7274 - val_loss: 0.9918 - val_accuracy: 0.7319
# Epoch 43/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9825 - accuracy: 0.7317
# Epoch 43: loss improved from 0.98917 to 0.98255, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 298s 865ms/step - loss: 0.9825 - accuracy: 0.7317 - val_loss: 0.9810 - val_accuracy: 0.7312
# Epoch 44/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9756 - accuracy: 0.7312
# Epoch 44: loss improved from 0.98255 to 0.97563, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 299s 867ms/step - loss: 0.9756 - accuracy: 0.7312 - val_loss: 0.9766 - val_accuracy: 0.7341
# Epoch 45/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9615 - accuracy: 0.7364
# Epoch 45: loss improved from 0.97563 to 0.96150, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 301s 872ms/step - loss: 0.9615 - accuracy: 0.7364 - val_loss: 0.9697 - val_accuracy: 0.7377
# Epoch 46/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9532 - accuracy: 0.7496
# Epoch 46: loss improved from 0.96150 to 0.95318, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 302s 875ms/step - loss: 0.9532 - accuracy: 0.7496 - val_loss: 0.9652 - val_accuracy: 0.7348
# Epoch 47/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9504 - accuracy: 0.7397
# Epoch 47: loss improved from 0.95318 to 0.95043, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 302s 876ms/step - loss: 0.9504 - accuracy: 0.7397 - val_loss: 0.9540 - val_accuracy: 0.7362
# Epoch 48/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9473 - accuracy: 0.7424
# Epoch 48: loss improved from 0.95043 to 0.94732, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 301s 872ms/step - loss: 0.9473 - accuracy: 0.7424 - val_loss: 0.9494 - val_accuracy: 0.7362
# Epoch 49/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9419 - accuracy: 0.7453
# Epoch 49: loss improved from 0.94732 to 0.94189, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 301s 872ms/step - loss: 0.9419 - accuracy: 0.7453 - val_loss: 0.9413 - val_accuracy: 0.7406
# Epoch 50/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9147 - accuracy: 0.7600
# Epoch 50: loss improved from 0.94189 to 0.91468, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 314s 910ms/step - loss: 0.9147 - accuracy: 0.7600 - val_loss: 0.9351 - val_accuracy: 0.7399
# Epoch 51/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9199 - accuracy: 0.7455
# Epoch 51: loss did not improve from 0.91468
# 345/345 [==============================] - 304s 880ms/step - loss: 0.9199 - accuracy: 0.7455 - val_loss: 0.9320 - val_accuracy: 0.7413
# Epoch 52/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9156 - accuracy: 0.7505
# Epoch 52: loss did not improve from 0.91468
# 345/345 [==============================] - 300s 870ms/step - loss: 0.9156 - accuracy: 0.7505 - val_loss: 0.9261 - val_accuracy: 0.7442
# Epoch 53/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9173 - accuracy: 0.7466
# Epoch 53: loss did not improve from 0.91468
# 345/345 [==============================] - 299s 866ms/step - loss: 0.9173 - accuracy: 0.7466 - val_loss: 0.9196 - val_accuracy: 0.7449
# Epoch 54/100
# 345/345 [==============================] - ETA: 0s - loss: 0.9000 - accuracy: 0.7495
# Epoch 54: loss improved from 0.91468 to 0.90004, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 301s 873ms/step - loss: 0.9000 - accuracy: 0.7495 - val_loss: 0.9145 - val_accuracy: 0.7413
# Epoch 55/100
# 345/345 [==============================] - ETA: 0s - loss: 0.8955 - accuracy: 0.7527
# Epoch 55: loss improved from 0.90004 to 0.89546, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 300s 869ms/step - loss: 0.8955 - accuracy: 0.7527 - val_loss: 0.9052 - val_accuracy: 0.7449
# Epoch 56/100
#  15/345 [>.............................] - ETA: 4:37 - loss: 0.9122 - accuracy: 0.7333

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# Tentukan path penyimpanan model
checkpoint_path = '/content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='val_loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=2)  # Menampilkan pesan saat menyimpan

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.2 and logs.get('val_loss') > 0.96):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
model = load_model(checkpoint_path)

callbacks= myCallback()
model.fit(train_data, validation_data=validasi_data, epochs=10, callbacks=([callbacks],[checkpoint_callback]))
# Out:
# Epoch 1/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8845 - accuracy: 0.7547
# Epoch 1: val_loss improved from inf to 0.90823, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 4398s 13s/step - loss: 0.8845 - accuracy: 0.7547 - val_loss: 0.9082 - val_accuracy: 0.7413
# Epoch 2/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8739 - accuracy: 0.7565
# Epoch 2: val_loss improved from 0.90823 to 0.90086, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1431s 4s/step - loss: 0.8739 - accuracy: 0.7565 - val_loss: 0.9009 - val_accuracy: 0.7442
# Epoch 3/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8727 - accuracy: 0.7563
# Epoch 3: val_loss improved from 0.90086 to 0.90058, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1394s 4s/step - loss: 0.8727 - accuracy: 0.7563 - val_loss: 0.9006 - val_accuracy: 0.7486
# Epoch 4/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8595 - accuracy: 0.7592
# Epoch 4: val_loss improved from 0.90058 to 0.89546, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1453s 4s/step - loss: 0.8595 - accuracy: 0.7592 - val_loss: 0.8955 - val_accuracy: 0.7420
# Epoch 5/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8570 - accuracy: 0.7620
# Epoch 5: val_loss improved from 0.89546 to 0.88908, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1417s 4s/step - loss: 0.8570 - accuracy: 0.7620 - val_loss: 0.8891 - val_accuracy: 0.7449
# Epoch 6/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8560 - accuracy: 0.7553
# Epoch 6: val_loss improved from 0.88908 to 0.88788, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1397s 4s/step - loss: 0.8560 - accuracy: 0.7553 - val_loss: 0.8879 - val_accuracy: 0.7384
# Epoch 7/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8476 - accuracy: 0.7674
# Epoch 7: val_loss improved from 0.88788 to 0.88195, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1385s 4s/step - loss: 0.8476 - accuracy: 0.7674 - val_loss: 0.8820 - val_accuracy: 0.7507
# Epoch 8/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8379 - accuracy: 0.7623
# Epoch 8: val_loss improved from 0.88195 to 0.87551, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1396s 4s/step - loss: 0.8379 - accuracy: 0.7623 - val_loss: 0.8755 - val_accuracy: 0.7413
# Epoch 9/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8413 - accuracy: 0.7611
# Epoch 9: val_loss improved from 0.87551 to 0.87436, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1402s 4s/step - loss: 0.8413 - accuracy: 0.7611 - val_loss: 0.8744 - val_accuracy: 0.7500
# Epoch 10/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8336 - accuracy: 0.7621
# Epoch 10: val_loss improved from 0.87436 to 0.86866, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1380s 4s/step - loss: 0.8336 - accuracy: 0.7621 - val_loss: 0.8687 - val_accuracy: 0.7522

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# Tentukan path penyimpanan model
checkpoint_path = '/content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='val_loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=2)  # Menampilkan pesan saat menyimpan

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('loss') < 0.2 and logs.get('val_loss') > 0.96):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
model = load_model(checkpoint_path)

callbacks= myCallback()
model.fit(train_data, validation_data=validasi_data, epochs=10, callbacks=([callbacks],[checkpoint_callback]))
# Out:
# Epoch 1/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8257 - accuracy: 0.7668
# Epoch 1: val_loss improved from inf to 0.86551, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1394s 4s/step - loss: 0.8257 - accuracy: 0.7668 - val_loss: 0.8655 - val_accuracy: 0.7442
# Epoch 2/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8264 - accuracy: 0.7750
# Epoch 2: val_loss improved from 0.86551 to 0.85968, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1368s 4s/step - loss: 0.8264 - accuracy: 0.7750 - val_loss: 0.8597 - val_accuracy: 0.7457
# Epoch 3/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8310 - accuracy: 0.7603
# Epoch 3: val_loss improved from 0.85968 to 0.85821, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1370s 4s/step - loss: 0.8310 - accuracy: 0.7603 - val_loss: 0.8582 - val_accuracy: 0.7551
# Epoch 4/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8117 - accuracy: 0.7712
# Epoch 4: val_loss improved from 0.85821 to 0.85795, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1387s 4s/step - loss: 0.8117 - accuracy: 0.7712 - val_loss: 0.8580 - val_accuracy: 0.7442
# Epoch 5/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8125 - accuracy: 0.7683
# Epoch 5: val_loss improved from 0.85795 to 0.85065, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1375s 4s/step - loss: 0.8125 - accuracy: 0.7683 - val_loss: 0.8506 - val_accuracy: 0.7500
# Epoch 6/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8074 - accuracy: 0.7696
# Epoch 6: val_loss improved from 0.85065 to 0.84790, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1392s 4s/step - loss: 0.8074 - accuracy: 0.7696 - val_loss: 0.8479 - val_accuracy: 0.7507
# Epoch 7/10
# 345/345 [==============================] - ETA: 0s - loss: 0.7961 - accuracy: 0.7774
# Epoch 7: val_loss improved from 0.84790 to 0.84141, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1371s 4s/step - loss: 0.7961 - accuracy: 0.7774 - val_loss: 0.8414 - val_accuracy: 0.7478
# Epoch 8/10
# 345/345 [==============================] - ETA: 0s - loss: 0.7965 - accuracy: 0.7679
# Epoch 8: val_loss did not improve from 0.84141
# 345/345 [==============================] - 1327s 4s/step - loss: 0.7965 - accuracy: 0.7679 - val_loss: 0.8437 - val_accuracy: 0.7493
# Epoch 9/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8052 - accuracy: 0.7694
# Epoch 9: val_loss improved from 0.84141 to 0.83785, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1387s 4s/step - loss: 0.8052 - accuracy: 0.7694 - val_loss: 0.8378 - val_accuracy: 0.7522
# Epoch 10/10
# 345/345 [==============================] - ETA: 0s - loss: 0.8052 - accuracy: 0.7708
# Epoch 10: val_loss improved from 0.83785 to 0.83361, saving model to /content/drive/MyDrive/BANGKIT 2023/Percobaan-MobileNetV2/MobileNetV2-1024-0.1.h5
# 345/345 [==============================] - 1329s 4s/step - loss: 0.8052 - accuracy: 0.7708 - val_loss: 0.8336 - val_accuracy: 0.7580

# %%
#plotting
import matplotlib.pyplot as plt
def display_training_curves(training, validation, title, subplot):

    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
#display
display_training_curves(
    mobilenetv2_history.history['loss'],
    mobilenetv2_history.history['val_loss'],
    'loss', 211)
display_training_curves(
    mobilenetv2_history.history['accuracy'],
    mobilenetv2_history.history['val_accuracy'],
    'accuracy', 212)

# %% [markdown]
# # Evaluation dan Prediction

# %%
# Predict the label of the test_images
import numpy as np
pred = model3.predict(validasi_data)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (validasi_data.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 10 predictions: {pred[:10]}')

# %%
#classification Report
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

y_test = list(val_df.Label)
print(classification_report(y_test, pred))

# %%
import seaborn as sns
import pandas as pd
cm  = confusion_matrix(pred,y_test)
df_cm = pd.DataFrame(cm, index = [i for i in range(10)],
                  columns = [i for i in range(10)])
sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d')
plt.title('confusion matrix')
plt.xlabel('prediction')
plt.ylabel('Actual');

# %%
# Display some pictures of the dataset with their labels and the predictions
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(val_df.Filepath.iloc[i]))
    ax.set_title(f"True: {val_df.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Save Model

# %%
MODEL_BASE_PATH = "/content/drive/MyDrive"
PROJECT_NAME = "Percobaan-ResNet50"
SAVE_MODEL_NAME = "Final100-ResNet-512-01.h5"
save_model_path = os.path.join(MODEL_BASE_PATH, PROJECT_NAME, SAVE_MODEL_NAME)
if os.path.exists(os.path.join(MODEL_BASE_PATH, PROJECT_NAME)) == False:
    os.makedirs(os.path.join(MODEL_BASE_PATH, PROJECT_NAME))

print('Saving Model At {}...'.format(save_model_path))
model3.save(save_model_path,include_optimizer=False)

# %% [markdown]
# # Lanjut Epoch Pake Checkpoint Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import os
os.chdir('C:/Users/ASUS/Dataset')
print(os.getcwd() + "\n")
# Out:
# C:\Users\ASUS\Dataset

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') > 0.96 and logs.get('val_accuracy') > 0.90):
      print("\Stopped, Akurasi mencapai 98%")
      self.model.stop_training = True;

# %%
# Tentukan path penyimpanan model
checkpoint_path = 'C:/Users/ASUS/Dataset/Hasil/Percobaan-Resnet50/model_resnet50-v1.h5'

# Buat callback ModelCheckpoint
checkpoint_callback = ModelCheckpoint(filepath=checkpoint_path,
                                      monitor='val_loss',  # Metrik yang akan dipantau
                                      save_best_only=True,  # Hanya menyimpan model terbaik
                                      save_weights_only=False,  # Menyimpan seluruh model
                                      mode='min',  # Mode pemantauan (misalnya, 'min', 'max', atau 'auto')
                                      verbose=1)  # Menampilkan pesan saat menyimpan

# %%
callbacks = myCallback()
resnet.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# %%
resnet_history = resnet.fit(train_data,
                            steps_per_epoch=train_data.n/16,
                            epochs=20,
                            validation_data=val_data,
                            validation_steps=val_data.n/16,
                            callbacks=([callbacks],[checkpoint_callback]),
                            verbose = 2
                            )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 resnet_history = resnet.fit(train_data,
#       2                             steps_per_epoch=train_data.n/16,
#       3                             epochs=20,
#       4                             validation_data=val_data,
#       5                             validation_steps=val_data.n/16,
#       6                             callbacks=([callbacks],[checkpoint_callback]),
#       7                             verbose = 2
#       8                             )
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py:1134, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1128   self._cluster_coordinator = tf.distribute.experimental.coordinator.ClusterCoordinator(
#    1129       self.distribute_strategy)
#    1131 with self.distribute_strategy.scope(), \
#    1132      training_utils.RespectCompiledTrainableState(self):
#    1133   # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1134   data_handler = data_adapter.get_data_handler(
#    1135       x=x,
#    1136       y=y,
#    1137       sample_weight=sample_weight,
#    1138       batch_size=batch_size,
#    1139       steps_per_epoch=steps_per_epoch,
#    1140       initial_epoch=initial_epoch,
#    1141       epochs=epochs,
#    1142       shuffle=shuffle,
#    1143       class_weight=class_weight,
#    1144       max_queue_size=max_queue_size,
#    1145       workers=workers,
#    1146       use_multiprocessing=use_multiprocessing,
#    1147       model=self,
#    1148       steps_per_execution=self._steps_per_execution)
#    1150   # Container that configures and calls `tf.keras.Callback`s.
#    1151   if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:1383, in get_data_handler(*args, **kwargs)
#    1381 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383 return DataHandler(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:1138, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1135   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1137 adapter_cls = select_data_adapter(x, y)
# -> 1138 self._adapter = adapter_cls(
#    1139     x,
#    1140     y,
#    1141     batch_size=batch_size,
#    1142     steps=steps_per_epoch,
#    1143     epochs=epochs - initial_epoch,
#    1144     sample_weights=sample_weight,
#    1145     shuffle=shuffle,
#    1146     max_queue_size=max_queue_size,
#    1147     workers=workers,
#    1148     use_multiprocessing=use_multiprocessing,
#    1149     distribution_strategy=tf.distribute.get_strategy(),
#    1150     model=model)
#    1152 strategy = tf.distribute.get_strategy()
#    1154 self._current_step = 0
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:917, in KerasSequenceAdapter.__init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     915 self._keras_sequence = x
#     916 self._enqueuer = None
# --> 917 super(KerasSequenceAdapter, self).__init__(
#     918     x,
#     919     shuffle=False,  # Shuffle is handed in the _make_callable override.
#     920     workers=workers,
#     921     use_multiprocessing=use_multiprocessing,
#     922     max_queue_size=max_queue_size,
#     923     model=model,
#     924     **kwargs)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:794, in GeneratorDataAdapter.__init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     790 super(GeneratorDataAdapter, self).__init__(x, y, **kwargs)
#     792 # Since we have to know the dtype of the python generator when we build the
#     793 # dataset, we have to look at a batch to infer the structure.
# --> 794 peek, x = self._peek_and_restore(x)
#     795 peek = self._standardize_batch(peek)
#     796 peek = _process_tensorlike(peek)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\data_adapter.py:928, in KerasSequenceAdapter._peek_and_restore(x)
#     926 @staticmethod
#     927 def _peek_and_restore(x):
# --> 928   return x[0], x
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\iterator.py:65, in Iterator.__getitem__(self, idx)
#      62     self._set_index_array()
#      63 index_array = self.index_array[self.batch_size * idx:
#      64                                self.batch_size * (idx + 1)]
# ---> 65 return self._get_batches_of_transformed_samples(index_array)
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\iterator.py:227, in BatchFromFilesMixin._get_batches_of_transformed_samples(self, index_array)
#     225 filepaths = self.filepaths
#     226 for i, j in enumerate(index_array):
# --> 227     img = load_img(filepaths[j],
#     228                    color_mode=self.color_mode,
#     229                    target_size=self.target_size,
#     230                    interpolation=self.interpolation)
#     231     x = img_to_array(img, data_format=self.data_format)
#     232     # Pillow images should be closed after `load_img`,
#     233     # but not PIL images.
#
# File C:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\keras_preprocessing\image\utils.py:113, in load_img(path, grayscale, color_mode, target_size, interpolation)
#     110 if pil_image is None:
#     111     raise ImportError('Could not import PIL.Image. '
#     112                       'The use of `load_img` requires PIL.')
# --> 113 with open(path, 'rb') as f:
#     114     img = pil_image.open(io.BytesIO(f.read()))
#     115     if color_mode == 'grayscale':
#     116         # if image is not already an 8-bit, 16-bit or 32-bit grayscale image
#     117         # convert it to an 8-bit grayscale image.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Ikan Kerapu\\IMG_20230519_110110_jpg.rf.6007c179833f9823ca2971290de5382c.jpg'

# %% [markdown]
# # Predict new data

# %%
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#Input Gambar
# %matplotlib inline
uploaded = files.upload()

for fn in uploaded.keys():

  # predicting images
  path = fn
  img = image.load_img(path, target_size=(416,416))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = resnet.predict(images, batch_size=10)
  print(classes)
  if classes[0][0] == 1:
    print('Penyu Hijau')
  elif classes[0][1] == 1:
    print('Penyu Lekang')
  elif classes[0][2] == 1:
    print('Penyu Sisik')
  elif classes[0][3] == 1:
    print('Penyu Tempayan')
